# %%
import gymnasium as gym
import my_envs
from stable_baselines3 import PPO
import numpy
import matplotlib.pyplot as plt

# %%
import datetime

# %%
now = datetime.datetime.now()
# run_prefix = datetime.datetime.strftime(now, '%Y-%m-%d-%H-%M')
run_prefix = 'my_run'
print(run_prefix)
# Out:
# my_run

# %%
env = gym.make("biped",render_mode='none')

# %%
model = PPO("MlpPolicy", env, verbose=1,tensorboard_log='log/'+run_prefix+'/')
model.learn(total_timesteps=30000,tb_log_name="first_run")
model.save(run_prefix+'-1.zip')
env.close()

# %%
env = gym.make("biped",render_mode='none')
model = PPO.load(run_prefix+'-1.zip', env=env)
model.learn(total_timesteps=50000,tb_log_name="second_run", reset_num_timesteps=False)
model.save(run_prefix+'-2.zip')
env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/my_run/second_run_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -9.7     |
# | time/              |          |
# |    fps             | 561      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -9.59        |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0013178418 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.9704535    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00583      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00253     |
# |    std                  | 0.935        |
# |    value_loss           | 0.0689       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.95        |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017243397 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.9708215    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00961      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000183     |
# |    std                  | 0.925        |
# |    value_loss           | 0.0818       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.94       |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004688466 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.97749233  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0334      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000554   |
# |    std                  | 0.921       |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.34       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005231384 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.97270316  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 0.907       |
# |    value_loss           | 0.0281      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.02      |
# | time/                   |            |
# |    fps                  | 365        |
# |    iterations           | 6          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00501516 |
# |    clip_fraction        | 0.0286     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.63      |
# |    explained_variance   | 0.97457045 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00897    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00077   |
# |    std                  | 0.899      |
# |    value_loss           | 0.0361     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.54        |
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 7            |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0062708594 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.9804723    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0225       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00561     |
# |    std                  | 0.884        |
# |    value_loss           | 0.0421       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -5.9         |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 8            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0047232704 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.9774367    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00593     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.873        |
# |    value_loss           | 0.0346       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.34       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 9           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005925177 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.9691091   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0219      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.867       |
# |    value_loss           | 0.0414      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.84       |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 10          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005309514 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.972568    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0476      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000443   |
# |    std                  | 0.862       |
# |    value_loss           | 0.036       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -4.52        |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 11           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0053851185 |
# |    clip_fraction        | 0.0828       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.9720494    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.136        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0057      |
# |    std                  | 0.864        |
# |    value_loss           | 0.0458       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -4.39        |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 12           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0024705688 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.9658549    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0202       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000178     |
# |    std                  | 0.858        |
# |    value_loss           | 0.0419       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.27       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 13          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004721511 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.9743273   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.033       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0018     |
# |    std                  | 0.853       |
# |    value_loss           | 0.0536      |
# -----------------------------------------

# %%
env = gym.make("biped",render_mode='none')
model = PPO.load(run_prefix+'-2.zip', env=env)
model.learn(total_timesteps=50000,tb_log_name="third run", reset_num_timesteps=False)
model.save(run_prefix+'-2.zip')
env.close()
