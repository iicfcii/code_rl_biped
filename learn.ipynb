# %%
import gymnasium as gym
import my_envs
from stable_baselines3 import PPO
import numpy
import matplotlib.pyplot as plt

# %%
import datetime

# %%
now = datetime.datetime.now()
run_prefix = datetime.datetime.strftime(now, '%Y-%m-%d-%H-%M')
# run_prefix = 'my_run'
print(run_prefix)
# Out:
# 2024-10-17-18-26

# %%
env = gym.make("biped",render_mode='none')

# %%
model = PPO("MlpPolicy", env, verbose=1,tensorboard_log='log/'+run_prefix+'/')
model.learn(total_timesteps=10000,tb_log_name="first_run")
model.save(run_prefix+'-1.zip')
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/2024-10-17-18-26/first_run_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -13.1    |
# | time/              |          |
# |    fps             | 1263     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.32        |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.004501102  |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.023666143 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00313      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.999        |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -12.3        |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077633746 |
# |    clip_fraction        | 0.0906       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.20160455   |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0181      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00809     |
# |    std                  | 0.987        |
# |    value_loss           | 0.00567      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -12.9        |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0043609897 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.4595163    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00188      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.998        |
# |    value_loss           | 0.0184       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007396511 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.7856661   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0137     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00867    |
# |    std                  | 0.989       |
# |    value_loss           | 0.0204      |
# -----------------------------------------

# %%
env = gym.make("biped",render_mode='none')
model = PPO.load(run_prefix+'-1.zip', env=env)
model.learn(total_timesteps=200000,tb_log_name="second_run", reset_num_timesteps=False)
model.save(run_prefix+'-2.zip')
env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/2024-10-17-18-26/second_run_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -15      |
# | time/              |          |
# |    fps             | 1054     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 12288    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -15.7      |
# | time/                   |            |
# |    fps                  | 868        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00499905 |
# |    clip_fraction        | 0.0405     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.90042305 |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00336   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00252   |
# |    std                  | 0.976      |
# |    value_loss           | 0.04       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -15.9       |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005033173 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.91105235  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0855      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.977       |
# |    value_loss           | 0.0791      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -15.3        |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0042815283 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.9402628    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0434       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00413     |
# |    std                  | 0.966        |
# |    value_loss           | 0.0642       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007272167 |
# |    clip_fraction        | 0.084       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.9327289   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00072     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00662    |
# |    std                  | 0.967       |
# |    value_loss           | 0.0538      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14         |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007995362 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.95645577  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00162    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00844    |
# |    std                  | 0.965       |
# |    value_loss           | 0.0405      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006331717 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.9558238   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00355    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.964       |
# |    value_loss           | 0.0537      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007302895 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.95422685  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0439      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00728    |
# |    std                  | 0.947       |
# |    value_loss           | 0.0874      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -11.7        |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 9            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0066259988 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.9581599    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00534     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00379     |
# |    std                  | 0.941        |
# |    value_loss           | 0.0621       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007436102 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.95816094  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.929       |
# |    value_loss           | 0.0696      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -10.8        |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 11           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0011967849 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.9745435    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.034        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000173    |
# |    std                  | 0.923        |
# |    value_loss           | 0.0478       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -10.9        |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 12           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0053971875 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.96333206   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0346       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00344     |
# |    std                  | 0.928        |
# |    value_loss           | 0.0539       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -10          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 13           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0038479366 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.9652138    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.184        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.912        |
# |    value_loss           | 0.183        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -9.9         |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 14           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0074010226 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.97061294   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0184       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00271     |
# |    std                  | 0.907        |
# |    value_loss           | 0.0585       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -9.84        |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 15           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0029261508 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.9530004    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.138        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.907        |
# |    value_loss           | 0.187        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -9.41        |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 16           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0054885624 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.9537986    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0606       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.908        |
# |    value_loss           | 0.166        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.98        |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 17           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0029919473 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.9696425    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0179       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.902        |
# |    value_loss           | 0.135        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.78       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006575787 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.95263106  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.16        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.886       |
# |    value_loss           | 0.194       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.45       |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004780433 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.97317106  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.07        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00072    |
# |    std                  | 0.878       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.3        |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004413942 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.962441    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000628   |
# |    std                  | 0.871       |
# |    value_loss           | 0.139       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.25        |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 21           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014353285 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.967305     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0193       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00029     |
# |    std                  | 0.853        |
# |    value_loss           | 0.133        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.51        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 22           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0068178764 |
# |    clip_fraction        | 0.0706       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.9412879    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.185        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00243     |
# |    std                  | 0.853        |
# |    value_loss           | 0.309        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.44        |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 23           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0013558166 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.9603543    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0444       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000912     |
# |    std                  | 0.85         |
# |    value_loss           | 0.0939       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.51        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 24           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0028127413 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.96699023   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0326       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000644    |
# |    std                  | 0.853        |
# |    value_loss           | 0.0734       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -8.29        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 25           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0023469864 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.9583672    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.062        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000592     |
# |    std                  | 0.851        |
# |    value_loss           | 0.127        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.25       |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 26          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002449303 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.9605314   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0473      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.000879   |
# |    std                  | 0.848       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.32       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 27          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005625363 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.9651251   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0244      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.837       |
# |    value_loss           | 0.0686      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -7.71        |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 28           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0044566225 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.9685735    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00535      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 0.842        |
# |    value_loss           | 0.136        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.66       |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 29          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002308425 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.9346113   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00971     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00235    |
# |    std                  | 0.851       |
# |    value_loss           | 0.0521      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -7.38        |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 30           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0020982146 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.51        |
# |    explained_variance   | 0.9738559    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0196       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000368     |
# |    std                  | 0.85         |
# |    value_loss           | 0.0767       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -7.36        |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 31           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0033693097 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.9535969    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0238       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000102     |
# |    std                  | 0.857        |
# |    value_loss           | 0.0578       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -7.32        |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 32           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0029507163 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.96390176   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000135     |
# |    std                  | 0.85         |
# |    value_loss           | 0.0898       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.78        |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 33           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0015183522 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.98257524   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0123       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.834        |
# |    value_loss           | 0.0639       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.53        |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 34           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0037360275 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.9642465    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0129       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000896    |
# |    std                  | 0.831        |
# |    value_loss           | 0.0296       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.25        |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 35           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0064401724 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.9739689    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00872      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.828        |
# |    value_loss           | 0.0557       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.23        |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 36           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0022101095 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.9772236    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00616      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000333    |
# |    std                  | 0.825        |
# |    value_loss           | 0.0355       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.26       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 37          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004705273 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.97372603  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0264      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00108    |
# |    std                  | 0.81        |
# |    value_loss           | 0.0618      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.07       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 38          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002883912 |
# |    clip_fraction        | 0.00479     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.98352057  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0526      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.000148    |
# |    std                  | 0.795       |
# |    value_loss           | 0.0601      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.04        |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 39           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035960553 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0.97780436   |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00472     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000921    |
# |    std                  | 0.785        |
# |    value_loss           | 0.0482       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -5.71        |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 40           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0049579795 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.97961104   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.776        |
# |    value_loss           | 0.0603       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.38       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 41          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002063881 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.97280836  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0333      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00134    |
# |    std                  | 0.789       |
# |    value_loss           | 0.0489      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.14       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 42          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007983978 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.97348666  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000341   |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00203    |
# |    std                  | 0.784       |
# |    value_loss           | 0.0353      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -4.87        |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 43           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0045839767 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.97032607   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0222       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.781        |
# |    value_loss           | 0.0554       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -4.56        |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 44           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0041842973 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 0.9834118    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.043        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 0.772        |
# |    value_loss           | 0.0302       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -4.33       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 45          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004229832 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.9751432   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00767     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000917   |
# |    std                  | 0.77        |
# |    value_loss           | 0.0322      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -4.18        |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 46           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0036351236 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.9778109    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0159       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00074     |
# |    std                  | 0.763        |
# |    value_loss           | 0.0359       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.81       |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 47          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.007324882 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.97664785  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000297   |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 0.757       |
# |    value_loss           | 0.0356      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.49       |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 48          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.000673952 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0.97548723  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0006      |
# |    std                  | 0.753       |
# |    value_loss           | 0.061       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -3.11        |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 49           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0077353325 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.9783184    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00613      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.743        |
# |    value_loss           | 0.0563       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -2.86       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 50          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.002547165 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.9782873   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.000345    |
# |    std                  | 0.742       |
# |    value_loss           | 0.0466      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -2.61        |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 51           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0021333643 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.9742353    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0223       |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.732        |
# |    value_loss           | 0.0815       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -2.2         |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 52           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0069954963 |
# |    clip_fraction        | 0.0874       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.9777771    |
# |    learning_rate        | 0.0003       |
# ...
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -0.348     |
# | time/                   |            |
# |    fps                  | 760        |
# |    iterations           | 82         |
# |    time_elapsed         | 220        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.00596397 |
# |    clip_fraction        | 0.0461     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | 0.98427135 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0253     |
# |    n_updates            | 860        |
# |    policy_gradient_loss | 0.000162   |
# |    std                  | 0.588      |
# |    value_loss           | 0.0655     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -0.203       |
# | time/                   |              |
# |    fps                  | 761          |
# |    iterations           | 83           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0058531435 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.98996556   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0428       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00145     |
# |    std                  | 0.588        |
# |    value_loss           | 0.0478       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -0.0416     |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 84          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.003958961 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.989896    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.000168    |
# |    std                  | 0.585       |
# |    value_loss           | 0.0477      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.06         |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 85           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0030665977 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.9786361    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0363       |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.000376     |
# |    std                  | 0.584        |
# |    value_loss           | 0.0588       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.12         |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 86           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0038766486 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.9845019    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0257       |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.000632    |
# |    std                  | 0.576        |
# |    value_loss           | 0.0508       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.435        |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 87           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0058098813 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.96743774   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0841       |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.576        |
# |    value_loss           | 0.0636       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.714        |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 88           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0039090402 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.98630303   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0142       |
# |    n_updates            | 920          |
# |    policy_gradient_loss | 0.000733     |
# |    std                  | 0.572        |
# |    value_loss           | 0.0452       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 0.783        |
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 89           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0056701563 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.9290397    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00426      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 1.16e-05     |
# |    std                  | 0.57         |
# |    value_loss           | 0.0709       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 90          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007597043 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.98225826  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0301      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00159    |
# |    std                  | 0.562       |
# |    value_loss           | 0.0445      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.38         |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 91           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0075774034 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | 0.98774177   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.003        |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.556        |
# |    value_loss           | 0.0262       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1.59         |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 92           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0030190763 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.64        |
# |    explained_variance   | 0.98271275   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0791       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.544        |
# |    value_loss           | 0.037        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 93          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.005125696 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.97565407  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00497     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00214    |
# |    std                  | 0.549       |
# |    value_loss           | 0.0435      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 2.09         |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 94           |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 202752       |
# | train/                  |              |
# |    approx_kl            | 0.0040745204 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 0.96578735   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0183       |
# |    n_updates            | 980          |
# |    policy_gradient_loss | 0.000125     |
# |    std                  | 0.543        |
# |    value_loss           | 0.063        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 2.2          |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 95           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0039885407 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 0.9789502    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0227       |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.000583    |
# |    std                  | 0.548        |
# |    value_loss           | 0.0523       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.4         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 96          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 206848      |
# | train/                  |             |
# |    approx_kl            | 0.005997942 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.98022     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00643    |
# |    std                  | 0.543       |
# |    value_loss           | 0.055       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.51        |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 97          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.004207157 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.9744049   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0416      |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.541       |
# |    value_loss           | 0.0638      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 3.01         |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 98           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 210944       |
# | train/                  |              |
# |    approx_kl            | 0.0063222367 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.977527     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00759      |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00342     |
# |    std                  | 0.533        |
# |    value_loss           | 0.0614       |
# ------------------------------------------

# %%
env = gym.make("biped",render_mode='none')
model = PPO.load(run_prefix+'-2.zip', env=env)
model.learn(total_timesteps=500000,tb_log_name="second_run", reset_num_timesteps=False)
model.save(run_prefix+'-3.zip')
env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/2024-10-17-18-26/second_run_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.15     |
# | time/              |          |
# |    fps             | 1376     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 212992   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 3.58         |
# | time/                   |              |
# |    fps                  | 1038         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0075307777 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | 0.97778386   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00627      |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00611     |
# |    std                  | 0.527        |
# |    value_loss           | 0.0572       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.64        |
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.006723549 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.9723524   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.515       |
# |    value_loss           | 0.0563      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.08        |
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 219136      |
# | train/                  |             |
# |    approx_kl            | 0.007817631 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.98073786  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00611     |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.000123   |
# |    std                  | 0.503       |
# |    value_loss           | 0.0463      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 4.47         |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0063202158 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.9820296    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0222       |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00157     |
# |    std                  | 0.497        |
# |    value_loss           | 0.0516       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.88        |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 223232      |
# | train/                  |             |
# |    approx_kl            | 0.001691842 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.9823014   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | 0.000277    |
# |    std                  | 0.497       |
# |    value_loss           | 0.0592      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 5.01        |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.002496372 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.9719427   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0384      |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | 0.000407    |
# |    std                  | 0.495       |
# |    value_loss           | 0.0833      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.06         |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 8            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 227328       |
# | train/                  |              |
# |    approx_kl            | 0.0051591713 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.9872409    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0246       |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00427     |
# |    std                  | 0.488        |
# |    value_loss           | 0.0437       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 5.83         |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0037781028 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.9716977    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 0.487        |
# |    value_loss           | 0.0513       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 6.24        |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.007177401 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.97579014  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0191      |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00295    |
# |    std                  | 0.493       |
# |    value_loss           | 0.0589      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 6.71        |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.005148869 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.9857546   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00667     |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00276    |
# |    std                  | 0.483       |
# |    value_loss           | 0.0514      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 7.47        |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 12          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 235520      |
# | train/                  |             |
# |    approx_kl            | 0.004969794 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.9791145   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0285      |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | 0.000607    |
# |    std                  | 0.48        |
# |    value_loss           | 0.0858      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 7.8          |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 13           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0031712106 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.98776346   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0377       |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00252     |
# |    std                  | 0.469        |
# |    value_loss           | 0.0721       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 8.39         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 14           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 239616       |
# | train/                  |              |
# |    approx_kl            | 0.0029135444 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.9808925    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0367       |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | 0.0011       |
# |    std                  | 0.463        |
# |    value_loss           | 0.0569       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.83        |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 15          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.007565477 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.9831751   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00443    |
# |    std                  | 0.457       |
# |    value_loss           | 0.0638      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 9.18       |
# | time/                   |            |
# |    fps                  | 841        |
# |    iterations           | 16         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 243712     |
# | train/                  |            |
# |    approx_kl            | 0.00548431 |
# |    clip_fraction        | 0.0634     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.98769474 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00158    |
# |    n_updates            | 1180       |
# |    policy_gradient_loss | -0.00269   |
# |    std                  | 0.457      |
# |    value_loss           | 0.071      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 9.59         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 17           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0059291767 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.9817909    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0376       |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.00394     |
# |    std                  | 0.449        |
# |    value_loss           | 0.0487       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 9.99        |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 18          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 247808      |
# | train/                  |             |
# |    approx_kl            | 0.003324729 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.98698413  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00874     |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00122    |
# |    std                  | 0.448       |
# |    value_loss           | 0.0669      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.5        |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 249856      |
# | train/                  |             |
# |    approx_kl            | 0.009027689 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.9871842   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.00751    |
# |    std                  | 0.444       |
# |    value_loss           | 0.0668      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 20          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 251904      |
# | train/                  |             |
# |    approx_kl            | 0.008932305 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.9824541   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00889     |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00633    |
# |    std                  | 0.442       |
# |    value_loss           | 0.0472      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 842          |
# |    iterations           | 21           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0057327887 |
# |    clip_fraction        | 0.0607       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.9838696    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0402       |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | 0.000454     |
# |    std                  | 0.438        |
# |    value_loss           | 0.0703       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 22          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 256000      |
# | train/                  |             |
# |    approx_kl            | 0.008555983 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.9779593   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0364      |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00531    |
# |    std                  | 0.438       |
# |    value_loss           | 0.0521      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 23          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.008644883 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.9796285   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00814     |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.43        |
# |    value_loss           | 0.0492      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 13.9         |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 24           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 260096       |
# | train/                  |              |
# |    approx_kl            | 0.0033756646 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.9837525    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00394      |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.422        |
# |    value_loss           | 0.0485       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 14.3       |
# | time/                   |            |
# |    fps                  | 844        |
# |    iterations           | 25         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.00707395 |
# |    clip_fraction        | 0.0497     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.982277   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0277     |
# |    n_updates            | 1270       |
# |    policy_gradient_loss | -0.00118   |
# |    std                  | 0.415      |
# |    value_loss           | 0.0664     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 26          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.003936353 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.982938    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0211      |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.000863   |
# |    std                  | 0.411       |
# |    value_loss           | 0.0744      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 27          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.008225167 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.98749095  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0528      |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00155    |
# |    std                  | 0.405       |
# |    value_loss           | 0.0643      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 28          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 268288      |
# | train/                  |             |
# |    approx_kl            | 0.007672755 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.98851955  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0205      |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.394       |
# |    value_loss           | 0.0742      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 29          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.005490717 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.9863897   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0281      |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | 0.000658    |
# |    std                  | 0.386       |
# |    value_loss           | 0.0663      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 17.9       |
# | time/                   |            |
# |    fps                  | 839        |
# |    iterations           | 30         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 272384     |
# | train/                  |            |
# |    approx_kl            | 0.00794618 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.917     |
# |    explained_variance   | 0.9828425  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0527     |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | -0.000411  |
# |    std                  | 0.385      |
# |    value_loss           | 0.0711     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 31          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.005867591 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.98242545  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0291      |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.00074     |
# |    std                  | 0.38        |
# |    value_loss           | 0.0595      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 32           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0061685024 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.96506304   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.038        |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.379        |
# |    value_loss           | 0.067        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 19.6         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 33           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0023398965 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.859       |
# |    explained_variance   | 0.97727203   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0505       |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | 4.51e-05     |
# |    std                  | 0.371        |
# |    value_loss           | 0.0803       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 20.2         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 34           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0047919396 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.98242027   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0025       |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 0.364        |
# |    value_loss           | 0.0639       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 35          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.005328673 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.98518926  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | 0.000694    |
# |    std                  | 0.367       |
# |    value_loss           | 0.0538      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 36          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.008103233 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.97860956  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00556    |
# |    std                  | 0.363       |
# |    value_loss           | 0.0542      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.3         |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 37           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0067094844 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.979915     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 0.358        |
# |    value_loss           | 0.0737       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 21.8         |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 38           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0048447894 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.96132505   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.057        |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -1.64e-05    |
# |    std                  | 0.358        |
# |    value_loss           | 0.056        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 22.3        |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 39          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.006003499 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.98398274  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0783      |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.000105   |
# |    std                  | 0.356       |
# |    value_loss           | 0.0711      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 22.5         |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 40           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0056255655 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.9878443    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00324      |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | 0.000271     |
# |    std                  | 0.354        |
# |    value_loss           | 0.0633       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 831         |
# |    iterations           | 41          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004962063 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.9767463   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.000578    |
# |    std                  | 0.354       |
# |    value_loss           | 0.0666      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 23.9        |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 42          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.007473758 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.9784058   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00338    |
# |    std                  | 0.347       |
# |    value_loss           | 0.0576      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 43          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.008980082 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.978976    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000625    |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 0.341       |
# |    value_loss           | 0.0559      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 44          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.007210236 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.97911364  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0643      |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.00146     |
# |    std                  | 0.336       |
# |    value_loss           | 0.0609      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 25.7         |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 45           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0054848865 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.9834495    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0205       |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -0.00238     |
# |    std                  | 0.329        |
# |    value_loss           | 0.0494       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 26.6         |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 46           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 305152       |
# | train/                  |              |
# |    approx_kl            | 0.0077145416 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.9869721    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00836     |
# |    n_updates            | 1480         |
# |    policy_gradient_loss | -0.000391    |
# |    std                  | 0.323        |
# |    value_loss           | 0.0515       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 27.5         |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 47           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0056555658 |
# |    clip_fraction        | 0.09         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.98117495   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0266       |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.000623    |
# |    std                  | 0.317        |
# |    value_loss           | 0.0593       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 28.7       |
# | time/                   |            |
# |    fps                  | 828        |
# |    iterations           | 48         |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 309248     |
# | train/                  |            |
# |    approx_kl            | 0.00831628 |
# |    clip_fraction        | 0.084      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.513     |
# |    explained_variance   | 0.9840863  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0389     |
# |    n_updates            | 1500       |
# |    policy_gradient_loss | 0.0015     |
# |    std                  | 0.313      |
# |    value_loss           | 0.0564     |
# ----------------------------------------
