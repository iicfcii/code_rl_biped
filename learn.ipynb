# %%
import gymnasium as gym
from my_envs.biped import BipedEnv
from stable_baselines3 import PPO
import numpy
import matplotlib.pyplot as plt
import datetime
import torch

# %%
now = datetime.datetime.now()
run_prefix = datetime.datetime.strftime(now, '%Y-%m-%d-%H-%M')

# %%
env = gym.make('biped',render_mode='none',max_episode_steps=BipedEnv.max_steps)
model = PPO(
    "MlpPolicy", env, seed=3,
    # n_steps=4096,
    # policy_kwargs={'activation_fn':torch.nn.ELU},
    verbose=1,tensorboard_log='log/'+run_prefix+'/'
)
model.learn(total_timesteps=500000,tb_log_name='run')
model.save(run_prefix+'_run_1.zip')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/2024-10-18-03-38/run_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -25      |
# | time/              |          |
# |    fps             | 2317     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 500       |
# |    ep_rew_mean          | -26.2     |
# | time/                   |           |
# |    fps                  | 1712      |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0093448 |
# |    clip_fraction        | 0.0809    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.81     |
# |    explained_variance   | -1.61363  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0638    |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.00859  |
# |    std                  | 0.977     |
# |    value_loss           | 0.135     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008981608 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.1894713   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0776      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00846    |
# |    std                  | 0.952       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -26.9        |
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0058383686 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.54611075   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0403       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00586     |
# |    std                  | 0.933        |
# |    value_loss           | 0.117        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -26.7        |
# | time/                   |              |
# |    fps                  | 1129         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0050474294 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.69999886   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00872      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00595     |
# |    std                  | 0.915        |
# |    value_loss           | 0.0964       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 1099        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009785201 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.7717205   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00047     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.889       |
# |    value_loss           | 0.0953      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -24.7       |
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008937436 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.72755885  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0022      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.873       |
# |    value_loss           | 0.0806      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -24.1        |
# | time/                   |              |
# |    fps                  | 1058         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062699034 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 0.61046255   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0207       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.847        |
# |    value_loss           | 0.0483       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -23.8       |
# | time/                   |             |
# |    fps                  | 1035        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009189242 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.02640313  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0804      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 0.817       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -23.1       |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013220913 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.4241106   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0344      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.798       |
# |    value_loss           | 0.0719      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -23         |
# | time/                   |             |
# |    fps                  | 1016        |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009008138 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.42522758  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0514      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00727    |
# |    std                  | 0.783       |
# |    value_loss           | 0.0759      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -22.4        |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 12           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0052221688 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.5049068    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0377       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00442     |
# |    std                  | 0.775        |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 13          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009128277 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.73064697  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00881     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 0.749       |
# |    value_loss           | 0.0632      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -21.5       |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 14          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011985497 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.7903027   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0129      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.728       |
# |    value_loss           | 0.0675      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -21.9        |
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 15           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053300187 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.5377921    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0585       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.719        |
# |    value_loss           | 0.114        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -23.6       |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 16          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005231772 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | -0.943491   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0739      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00343    |
# |    std                  | 0.713       |
# |    value_loss           | 0.374       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -23.9       |
# | time/                   |             |
# |    fps                  | 996         |
# |    iterations           | 17          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003423599 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.43227327  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00233    |
# |    std                  | 0.712       |
# |    value_loss           | 0.838       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -23.5        |
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 18           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0069734743 |
# |    clip_fraction        | 0.0751       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.83368105   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0616       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00676     |
# |    std                  | 0.708        |
# |    value_loss           | 0.352        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -23.4       |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 19          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010932278 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.86384076  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0936      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.703       |
# |    value_loss           | 0.234       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -24.2        |
# | time/                   |              |
# |    fps                  | 999          |
# |    iterations           | 20           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0077118594 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | -0.9494262   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0379       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00612     |
# |    std                  | 0.695        |
# |    value_loss           | 0.183        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 21          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006052667 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.5092267   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.188       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00533    |
# |    std                  | 0.69        |
# |    value_loss           | 0.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 22          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007313518 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.820572    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.163       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00574    |
# |    std                  | 0.691       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -25.1       |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 23          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008937991 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.9300716   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0955      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00994    |
# |    std                  | 0.692       |
# |    value_loss           | 0.372       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | -24.5        |
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 24           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0097845765 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.658268     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0296       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.68         |
# |    value_loss           | 0.0777       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -24.8       |
# | time/                   |             |
# |    fps                  | 1003        |
# |    iterations           | 25          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011719193 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.8270443   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0259      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.665       |
# |    value_loss           | 0.0696      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 26          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004503851 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.4666341   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.673       |
# |    value_loss           | 0.442       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -24.3       |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 27          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007496644 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.8568507   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.07        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00758    |
# |    std                  | 0.669       |
# |    value_loss           | 0.308       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -23.6        |
# | time/                   |              |
# |    fps                  | 1008         |
# |    iterations           | 28           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0057605333 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0.8908394    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.064        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00537     |
# |    std                  | 0.666        |
# |    value_loss           | 0.121        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -22.9       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 29          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008379877 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.5662495   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0404      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.642       |
# |    value_loss           | 0.0546      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -22.2        |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 30           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0070043984 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.6289456    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0184       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00519     |
# |    std                  | 0.626        |
# |    value_loss           | 0.0399       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -21.5       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 31          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011482086 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.68804675  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000798   |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.606       |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 32          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005241707 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.5506959   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0142      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00737    |
# |    std                  | 0.593       |
# |    value_loss           | 0.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -20         |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 33          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009704869 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.5230838   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0088     |
# |    std                  | 0.575       |
# |    value_loss           | 0.0586      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 34          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006117708 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.613261    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.013       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.57        |
# |    value_loss           | 0.0809      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -18.4        |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 35           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0062851994 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.6837313    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0226       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00764     |
# |    std                  | 0.554        |
# |    value_loss           | 0.0557       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 36          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005726622 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.6782477   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00564    |
# |    std                  | 0.543       |
# |    value_loss           | 0.0648      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 37           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0060466207 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.67984986   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00629     |
# |    std                  | 0.531        |
# |    value_loss           | 0.0592       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -16.4       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 38          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008538224 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.67085874  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0207      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0062     |
# |    std                  | 0.521       |
# |    value_loss           | 0.0661      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -15.4       |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 39          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007489443 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.75631285  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.028       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00676    |
# |    std                  | 0.511       |
# |    value_loss           | 0.045       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -12.7       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 40          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008384142 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.7042924   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00573     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00694    |
# |    std                  | 0.5         |
# |    value_loss           | 0.054       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 41          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007953739 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.7115247   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0438      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00586    |
# |    std                  | 0.488       |
# |    value_loss           | 0.0618      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -10.4       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 42          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007009508 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.7599574   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00555     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00267    |
# |    std                  | 0.48        |
# |    value_loss           | 0.0561      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -9.34       |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 43          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006913917 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.7757534   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00784     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00477    |
# |    std                  | 0.477       |
# |    value_loss           | 0.0471      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -7.54        |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 44           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0062535475 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.7599241    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00093      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00348     |
# |    std                  | 0.469        |
# |    value_loss           | 0.0507       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | -5.47       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 45          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008675184 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.70466185  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00675    |
# |    std                  | 0.459       |
# |    value_loss           | 0.048       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | -3.49        |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 46           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0061913347 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.5838961    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00495     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00463     |
# |    std                  | 0.452        |
# |    value_loss           | 0.0452       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | -2.56        |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 47           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0048509296 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.8041916    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00844      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00435     |
# |    std                  | 0.443        |
# |    value_loss           | 0.0214       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | -1.81       |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 48          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010060661 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.76529753  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00486    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.435       |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -0.641      |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 49          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011943835 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.7769358   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00751    |
# |    std                  | 0.428       |
# |    value_loss           | 0.0366      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 50          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004694065 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.7456289   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.427       |
# |    value_loss           | 0.0295      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 2.81         |
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 51           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0057048164 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.8288037    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0171       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 0.421        |
# |    value_loss           | 0.0188       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 3.71         |
# | time/                   |              |
# |    fps                  | 1006         |
# |    iterations           | 52           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0071743927 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.7426312    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -8.44e-05    |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0037      |
# |    std                  | 0.413        |
# |    value_loss           | 0.0252       |
# ------------------------------------------
# -----------------------------------------
# ...
# |    loss                 | -0.00259    |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.00225     |
# |    std                  | 0.123       |
# |    value_loss           | 0.00722     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 229         |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.010122484 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.37        |
# |    explained_variance   | 0.76528883  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0455     |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.000964   |
# |    std                  | 0.121       |
# |    value_loss           | 0.00681     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 230         |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.009949682 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.73757076  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00587     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000613   |
# |    std                  | 0.119       |
# |    value_loss           | 0.00833     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 231         |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.015048773 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.68711877  |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00788    |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -6.28e-05   |
# |    std                  | 0.121       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 232         |
# |    time_elapsed         | 494         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.011484957 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | 0.78695726  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0196      |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.000721   |
# |    std                  | 0.119       |
# |    value_loss           | 0.00646     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 961        |
# |    iterations           | 233        |
# |    time_elapsed         | 496        |
# |    total_timesteps      | 477184     |
# | train/                  |            |
# |    approx_kl            | 0.01138519 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.44       |
# |    explained_variance   | 0.7814722  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0278    |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | 0.00161    |
# |    std                  | 0.117      |
# |    value_loss           | 0.0067     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 234         |
# |    time_elapsed         | 498         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.018533597 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.46        |
# |    explained_variance   | 0.8369905   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0586      |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | 0.0013      |
# |    std                  | 0.116       |
# |    value_loss           | 0.00527     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 235         |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.009559846 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.49        |
# |    explained_variance   | 0.8014517   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0118      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | 0.000226    |
# |    std                  | 0.115       |
# |    value_loss           | 0.00687     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 236         |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.011335864 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.49        |
# |    explained_variance   | 0.8288031   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000168    |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.0016      |
# |    std                  | 0.115       |
# |    value_loss           | 0.00536     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 237          |
# |    time_elapsed         | 504          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0151736885 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.49         |
# |    explained_variance   | 0.7975103    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00369      |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | 0.0023       |
# |    std                  | 0.115        |
# |    value_loss           | 0.00813      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 238         |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.016475271 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.51        |
# |    explained_variance   | 0.8653586   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 7.55e-05    |
# |    std                  | 0.114       |
# |    value_loss           | 0.00448     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 239         |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.009923656 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.52        |
# |    explained_variance   | 0.8381798   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00662     |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00184     |
# |    std                  | 0.112       |
# |    value_loss           | 0.0056      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 240         |
# |    time_elapsed         | 511         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.010079714 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.54        |
# |    explained_variance   | 0.849245    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00989     |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.00216     |
# |    std                  | 0.112       |
# |    value_loss           | 0.00536     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 241         |
# |    time_elapsed         | 513         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.015747808 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.55        |
# |    explained_variance   | 0.86348474  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | 0.0034      |
# |    std                  | 0.111       |
# |    value_loss           | 0.00536     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 242         |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.018283123 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | 0.85052156  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0388      |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.00387     |
# |    std                  | 0.11        |
# |    value_loss           | 0.00542     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 19.3         |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 243          |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0104942955 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.57         |
# |    explained_variance   | 0.8695899    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0314       |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.11         |
# |    value_loss           | 0.005        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 244         |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.014874412 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | 0.8689914   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00414     |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.00227     |
# |    std                  | 0.11        |
# |    value_loss           | 0.00462     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 245         |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.012454558 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.59        |
# |    explained_variance   | 0.8543796   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00987     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | 0.00163     |
# |    std                  | 0.109       |
# |    value_loss           | 0.00383     |
# -----------------------------------------
